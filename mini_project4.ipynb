# %% [markdown]
# <a href="https://colab.research.google.com/github/TashiNyangmi/CEO_Jobs_Council/blob/master/mini_project4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/cuny_lagcc_micro_credential_data_analytics/main/Track%20A/Unit%204%20-%20Machine%20Learning%20and%20Modeling%20Techniques/Dataset/diabetic_data.csv')

# %%
# predict readmitted

# %%
df.shape
# Out:
# (101766, 50)

# %%
df = df.replace('?',np.NaN) # replace all ? with NaNs

# %%
round((df.isna().sum()/ len(df) * 100),2)
# Out:
# encounter_id                 0.00
# patient_nbr                  0.00
# race                         2.23
# gender                       0.00
# age                          0.00
# weight                      96.86
# admission_type_id            0.00
# discharge_disposition_id     0.00
# admission_source_id          0.00
# time_in_hospital             0.00
# payer_code                  39.56
# medical_specialty           49.08
# num_lab_procedures           0.00
# num_procedures               0.00
# num_medications              0.00
# number_outpatient            0.00
# number_emergency             0.00
# number_inpatient             0.00
# diag_1                       0.02
# diag_2                       0.35
# diag_3                       1.40
# number_diagnoses             0.00
# max_glu_serum                0.00
# A1Cresult                    0.00
# metformin                    0.00
# repaglinide                  0.00
# nateglinide                  0.00
# ...

# %%
df_dropped = df.drop(['encounter_id', 'patient_nbr', 'weight', 'payer_code', 'medical_specialty'], axis = 1)

# %%
round((df.isna().sum()/ len(df) * 100),2)
# Out:
# encounter_id                 0.00
# patient_nbr                  0.00
# race                         2.23
# gender                       0.00
# age                          0.00
# weight                      96.86
# admission_type_id            0.00
# discharge_disposition_id     0.00
# admission_source_id          0.00
# time_in_hospital             0.00
# payer_code                  39.56
# medical_specialty           49.08
# num_lab_procedures           0.00
# num_procedures               0.00
# num_medications              0.00
# number_outpatient            0.00
# number_emergency             0.00
# number_inpatient             0.00
# diag_1                       0.02
# diag_2                       0.35
# diag_3                       1.40
# number_diagnoses             0.00
# max_glu_serum                0.00
# A1Cresult                    0.00
# metformin                    0.00
# repaglinide                  0.00
# nateglinide                  0.00
# ...

# %% [markdown]
# ## TEMP

# %%
df.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# ...

# %%
int_cols = ['admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 'number_inpatient', 'number_diagnoses']

# %%
all_cols = list(df.columns)

# %%
# for col in all_cols:
#   if col not in int_cols:
#     str_cols.append(col)

# %%
str_cols = [col for col in all_cols if col not in int_cols] # list comprehension

# %%
columns = str_cols
columns.remove('readmitted')

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
# feature columns
columns = ['race', 'age', 'A1Cresult','diabetesMed', 'insulin', ]

# %%
df
# Out:
#         encounter_id  patient_nbr  ... diabetesMed readmitted
# 0            2278392      8222157  ...          No         NO
# 1             149190     55629189  ...         Yes        >30
# 2              64410     86047875  ...         Yes         NO
# 3             500364     82442376  ...         Yes         NO
# 4              16680     42519267  ...         Yes         NO
# ...              ...          ...  ...         ...        ...
# 101761     443847548    100162476  ...         Yes        >30
# 101762     443847782     74694222  ...         Yes         NO
# 101763     443854148     41088789  ...         Yes         NO
# 101764     443857166     31693671  ...         Yes         NO
# 101765     443867222    175429310  ...          No         NO
#
# [101766 rows x 50 columns]

# %%
X = pd.get_dummies(df[columns], columns = columns, drop_first= True)

# %%
df
# Out:
#         encounter_id  patient_nbr  ... diabetesMed readmitted
# 0            2278392      8222157  ...          No         NO
# 1             149190     55629189  ...         Yes        >30
# 2              64410     86047875  ...         Yes         NO
# 3             500364     82442376  ...         Yes         NO
# 4              16680     42519267  ...         Yes         NO
# ...              ...          ...  ...         ...        ...
# 101761     443847548    100162476  ...         Yes        >30
# 101762     443847782     74694222  ...         Yes         NO
# 101763     443854148     41088789  ...         Yes         NO
# 101764     443857166     31693671  ...         Yes         NO
# 101765     443867222    175429310  ...          No         NO
#
# [101766 rows x 50 columns]

# %%
y = df['readmitted'].replace({'<30':1, '>30':2})

# %% [markdown]
# Temp End

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### EDA/ Visualization

# %%
df_dropped = df.drop(['encounter_id', 'patient_nbr', 'weight', 'payer_code', 'medical_specialty'], axis = 1)

# %% [markdown]
#  # MACHINE LEARNING

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
# X = data.drop('readmitted', axis = 1).values # features/ explanatory variables
# y = data['readmitted'].values # target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y) # split the data

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (76324, 20) (25442, 20) (76324,) (25442,)

# %%
rfmodel = RandomForestClassifier(n_estimators = 100, criterion = 'entropy') # intialize the model

# %%
rfmodel.fit(X_train, y_train) # fit the data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-60b51ae32913> in <module>()
# ----> 1 rfmodel.fit(X_train, y_train) # fit the data
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     319         self.n_outputs_ = y.shape[1]
#     320
# --> 321         y, expanded_class_weight = self._validate_y_class_weight(y)
#     322
#     323         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py in _validate_y_class_weight(self, y)
#     539
#     540     def _validate_y_class_weight(self, y):
# --> 541         check_classification_targets(y)
#     542
#     543         y = np.copy(y)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     164     y : array-like
# ...

# %%
y_pred = rfmodel.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(classification_report(y_test, y_pred))

# %%
print(confusion_matrix(y_test, y_pred))

# %%
confusion_matrix(y_test, y_pred)
